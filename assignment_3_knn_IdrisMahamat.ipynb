# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Data dictionary
# Species        category
# SepalLength       Int64
# SepalWidth        Int64
# PetalLength       Int64
# PetalWidth        Int64

# %%
data_types = {
    'Row_N0':     'Int64',
    'Sample': 'Int64',
    'F1':  'Int64',
    'F2':  'Int64',
    'F3':  'Int64',
    'F4':  'Int64',
    'Class':  'Int64'
}

file_path='/home/elcaskerito/Documents/Stevens/ml_eda_AI_stevens_institute_tech/file/HW_03_knn_BC_pfizer.csv'

# # Read CSV file with appropriate handling of missing values
df = pd.read_csv(file_path, na_values='?',dtype=data_types)

## Loading iris
# df = pd.read_csv('C:/Users/kdehn/OneDrive - stevens.edu/___Data/CSV_files/iris.csv',)

print(df.describe())
# #data preprocessing
## df['Species'] = pd.Categorical(df['Species'])  # convert Species column to categorical data type if needed
df.head(30)
# Out:
#          Row_N0          Sample        F1        F2        F3        F4  \
# count      30.0            30.0      30.0      30.0      30.0      30.0
# mean       15.5  1041365.133333  4.433333       2.6  2.666667  2.533333
# std    8.803408    20238.647148   2.68692  2.485822   2.48212  2.700362
# min         1.0       1000025.0       1.0       1.0       1.0       1.0
# 25%        8.25      1022190.25       2.0       1.0       1.0       1.0
# 50%        15.5       1046101.0       4.0       1.0       1.0       1.0
# 75%       22.75      1056236.25       6.0      3.75      3.75       3.0
# max        30.0       1070935.0      10.0      10.0      10.0      10.0
#
#           Class
# count      30.0
# mean        2.6
# std    0.932183
# min         2.0
# 25%         2.0
# 50%         2.0
# 75%         4.0
# max         4.0
#     Row_N0   Sample  F1  F2  F3  F4  Class
# 0        1  1000025   5   1   1   1      2
# 1        2  1002945   5   4   4   5      2
# 2        3  1015425   3   1   1   1      2
# 3        4  1016277   6   8   8   1      2
# 4        5  1017023   4   1   1   3      2
# 5        6  1017122   8  10  10   8      4
# 6        7  1018099   1   1   1   1      2
# 7        8  1018561   2   1   2   1      2
# 8        9  1033078   2   1   1   1      2
# 9       10  1033078   4   2   1   1      2
# 10      11  1035283   1   1   1   1      2
# 11      12  1036172   2   1   1   1      2
# 12      13  1041801   5   3   3   3      4
# 13      14  1043999   1   1   1   1      2
# 14      15  1044572   8   7   5  10      4
# 15      16  1047630   7   4   6   4      4
# 16      17  1048672   4   1   1   1      2
# 17      18  1049815   4   1   1   1      2
# 18      19  1050670  10   7   7   6      4
# 19      20  1050718   6   1   1   1      2
# 20      21  1054590   7   3   2  10      4
# 21      22  1054593  10   5   5   3      4
# 22      23  1056784   3   1   1   1      2
# 23      24  1057013   8   4   5   1      4
# 24      25  1059552   1   1   1   1      2
# 25      26  1065726   5   2   3   4      4
# 26      27  1066373   3   2   1   1      2
# 27      28  1066979   5   1   1   1      2
# 28      29  1067444   2   1   1   1      2
# 29      30  1070935   1   1   3   1      2

# %%
df.dtypes
# Out:
# Row_N0    Int64
# Sample    Int64
# F1        Int64
# F2        Int64
# F3        Int64
# F4        Int64
# Class     Int64
# dtype: object

# %%
# df = df.dropna() # drops NaN values 
# print(df[df.isna().any(axis=1)]) # shows NaN values in data frame if it exists

# Splitting the dataset

# df = df.drop(columns = ['Class'])  # features
# target = df['Class']  # target variable

testSet = df.iloc[[5, 11, 17,23, 29]]

trainSet = df.drop(index=[5, 11, 17,23, 29])


print(trainSet)



print('\n--------------------------------------- *test set start here*-------------------------- \n')



print(testSet.head(5))
# df.head(10)
# print(testSet)
# Out:
#     Row_N0   Sample  F1  F2  F3  F4  Class
# 0        1  1000025   5   1   1   1      2
# 1        2  1002945   5   4   4   5      2
# 2        3  1015425   3   1   1   1      2
# 3        4  1016277   6   8   8   1      2
# 4        5  1017023   4   1   1   3      2
# 6        7  1018099   1   1   1   1      2
# 7        8  1018561   2   1   2   1      2
# 8        9  1033078   2   1   1   1      2
# 9       10  1033078   4   2   1   1      2
# 10      11  1035283   1   1   1   1      2
# 12      13  1041801   5   3   3   3      4
# 13      14  1043999   1   1   1   1      2
# 14      15  1044572   8   7   5  10      4
# 15      16  1047630   7   4   6   4      4
# 16      17  1048672   4   1   1   1      2
# 18      19  1050670  10   7   7   6      4
# 19      20  1050718   6   1   1   1      2
# 20      21  1054590   7   3   2  10      4
# 21      22  1054593  10   5   5   3      4
# 22      23  1056784   3   1   1   1      2
# 24      25  1059552   1   1   1   1      2
# 25      26  1065726   5   2   3   4      4
# 26      27  1066373   3   2   1   1      2
# 27      28  1066979   5   1   1   1      2
# 28      29  1067444   2   1   1   1      2
#
# --------------------------------------- *test set start here*--------------------------
#
#     Row_N0   Sample  F1  F2  F3  F4  Class
# 5        6  1017122   8  10  10   8      4
# 11      12  1036172   2   1   1   1      2
# 17      18  1049815   4   1   1   1      2
# 23      24  1057013   8   4   5   1      4
# 29      30  1070935   1   1   3   1      2

# %%
from sklearn.preprocessing import MinMaxScaler
# Initialize MinMaxScaler
scaler = MinMaxScaler()
# Fit and transform the data
trainSet = pd.DataFrame(scaler.fit_transform(trainSet), columns=trainSet.columns)

print('\n--------------------------------------- *Scalling the data*-------------------------- \n')
trainSet.head()
# Out:
# --------------------------------------- *Scalling the data*--------------------------
#      Row_N0    Sample        F1        F2        F3        F4  Class
# 0  0.000000  0.000000  0.444444  0.000000  0.000000  0.000000    0.0
# 1  0.035714  0.043311  0.444444  0.428571  0.428571  0.444444    0.0
# 2  0.071429  0.228422  0.222222  0.000000  0.000000  0.000000    0.0
# 3  0.107143  0.241060  0.555556  1.000000  1.000000  0.000000    0.0
# 4  0.142857  0.252125  0.333333  0.000000  0.000000  0.222222    0.0

# %%
train_trainSet,test_trainSet, train_testSet, test_testSet = train_test_split(trainSet, testSet,test_size = 0.10, random_state = 7, shuffle = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 train_trainSet,test_trainSet, train_testSet, test_testSet = train_test_split(trainSet, testSet,test_size = 0.10, random_state = 7, shuffle = True)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_split.py:2848, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2845 if n_arrays == 0:
#    2846     raise ValueError("At least one array required as input")
# -> 2848 arrays = indexable(*arrays)
#    2850 n_samples = _num_samples(arrays[0])
#    2851 n_train, n_test = _validate_shuffle_split(
#    2852     n_samples, test_size, train_size, default_test_size=0.25
#    2853 )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:532, in indexable(*iterables)
#     502 """Make arrays indexable for cross-validation.
#     503
#     504 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     528 [[1, 2, 3], array([2, 3, 4]), None, <...Sparse...dtype 'int64'...shape (3, 1)>]
#     529 """
#     531 result = [_make_indexable(X) for X in iterables]
# --> 532 check_consistent_length(*result)
#     533 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:475, in check_consistent_length(*arrays)
#     473 uniques = np.unique(lengths)
#     474 if len(uniques) > 1:
# --> 475     raise ValueError(
#     476         "Found input variables with inconsistent numbers of samples: %r"
#     477         % [int(l) for l in lengths]
#     478     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [25, 5]

# %%
# from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
k_values = [1,2,3]

# for i in range(1,20):
#     print(i)
 
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors = k)
#     knn = KNeighborsClassifier(n_neighbors = k,weights='distance')
    knn.fit(train_trainSet, train_testSet)
    target_pred = knn.predict(test_trainSet)
#     accuracy = round(np.mean(target_test==target_pred ) * 100, 2)
    accuracy = accuracy_score(test_testSet,target_pred ) 
    print(f'Accuracy of model with k = {k}: {accuracy}')
    print('')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 11
#       9     knn = KNeighborsClassifier(n_neighbors = k)
#      10 #     knn = KNeighborsClassifier(n_neighbors = k,weights='distance')
# ---> 11     knn.fit(train_trainSet, train_testSet)
#      12     target_pred = knn.predict(test_trainSet)
#      13 #     accuracy = round(np.mean(target_test==target_pred ) * 100, 2)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/neighbors/_classification.py:239, in KNeighborsClassifier.fit(self, X, y)
#     217 @_fit_context(
#     218     # KNeighborsClassifier.metric is not validated yet
#     219     prefer_skip_nested_validation=False
#     220 )
#     221 def fit(self, X, y):
#     222     """Fit the k-nearest neighbors classifier from the training dataset.
#     223
#     224     Parameters
#    (...)
#     237         The fitted k-nearest neighbors classifier.
#     238     """
# --> 239     return self._fit(X, y)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/neighbors/_base.py:508, in NeighborsBase._fit(self, X, y)
#     505 else:
#     506     self.outputs_2d_ = True
# --> 508 check_classification_targets(y)
#     509 self.classes_ = []
#     510 # Using `dtype=np.intp` is necessary since `np.bincount`
#     511 # (called in _classification.py) fails when dealing
#     512 # with a float64 array on 32bit systems.
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/multiclass.py:222, in check_classification_targets(y)
#     214 y_type = type_of_target(y, input_name="y")
#     215 if y_type not in [
#     216     "binary",
#     217     "multiclass",
#    (...)
#     220     "multilabel-sequences",
#     221 ]:
# --> 222     raise ValueError(
#     223         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     224         "classifier, which expects discrete classes on a "
#     225         "regression target with continuous values."
#     226     )
#
# ValueError: Unknown label type: continuous-multioutput. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(target_test, target_pred)

print('Confusion Matrix')
print(confusion_matrix(target_test, target_pred))
print()
print('Accuracy score')
print(accuracy_score(target_test, target_pred))
print()
print('Classification Report')
print(classification_report(target_test, target_pred))
# Out:
# Confusion Matrix
# [[13  0  0]
#  [ 0 12  0]
#  [ 0  1 12]]
#
# Accuracy score
# 0.9736842105263158
#
# Classification Report
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        13
#   Versicolor       0.92      1.00      0.96        12
#    Virginica       1.00      0.92      0.96        13
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38

# %%
# target_pred.head()
test_actual=attr_test
test_actual['target_pred']=target_pred
test_actual['test_actual']=target_test
test_actual.head()
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth target_pred target_test  \
# 9       0.194444    0.625000     0.101695    0.208333      Setosa      Setosa
# 36      0.194444    0.625000     0.050847    0.083333      Setosa      Setosa
# 8       0.027778    0.500000     0.050847    0.041667      Setosa      Setosa
# 137     0.861111    0.333333     0.864407    0.750000   Virginica   Virginica
# 136     0.722222    0.500000     0.796610    0.916667   Virginica   Virginica
#
#     target_actual test_actual
# 9          Setosa      Setosa
# 36         Setosa      Setosa
# 8          Setosa      Setosa
# 137     Virginica   Virginica
# 136     Virginica   Virginica

# %%
#IV.	Displaying the frequency table of “PetalLength” vs. Species

freq_table =pd.crosstab( test_actual['test_actual'], test_actual['target_pred'])
print("Confusion Matrix")
print(freq_table)
# Out:
# target_pred  Setosa  Versicolor  Virginica
# test_actual
# Setosa           13           0          0
# Versicolor        0          12          0
# Virginica         0           1         12

# %% [markdown]
# ## Stop here. We do not use the code below

# %%
from sklearn.datasets import load_iris
iris_data = load_iris()
type(iris_data)

# %%
  
# # IMPORT THE IRIS DATA FROM THE 
# # SKLEARN MODULE
# from sklearn.datasets import load_iris
  
# # LOAD THE IRIS DATASET BY CALLING
# # THE FUNCTION
# iris_data = load_iris()
 
  
# # PLACE THE IRIS DATA IN A PANDAS
# # DATAFRAME
# attr = pd.DataFrame(data=iris_data.data, 
#                   columns=iris_data.feature_names)
# target =pd.DataFrame({'Species': iris_data.target})

# # DISPLAY FIRST 5 RECORDS OF THE 
# # DATAFRAME
# target.head()
# attr.head(10)
